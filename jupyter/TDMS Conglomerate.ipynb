# %% [markdown]
# Install npTDMS to actually pull in the TDMS files.

# %%
import sys
# !{sys.executable} -m pip install nptdms
# !{sys.executable} -m pip install numpy
# At least on my system, requirements already satisfied.
# Out:
# Requirement already satisfied: nptdms in /home/maxwell/snap/jupyter/common/lib/python3.7/site-packages (0.18.1)
# Requirement already satisfied: numpy in /home/maxwell/snap/jupyter/common/lib/python3.7/site-packages (from nptdms) (1.18.1)
# Requirement already satisfied: numpy in /home/maxwell/snap/jupyter/common/lib/python3.7/site-packages (1.18.1)

# %% [markdown]
# Import the tdmsfile reader capabilities from nptdms

# %%
import time as time
import numpy as np
from nptdms import TdmsFile
from pprint import pprint
import os
from os import walk
import shutil
import pathlib
from pathlib import Path
import csv
from itertools import chain

startTime = time.time()

# %% [markdown]
# ## Actually reading things in:
#
# The file structure currently isn't really nested the way we want it to be. We need to know:
#
# 1. How many parts are in our TDMS group.
# 2. How many layers total are in our TDMS group.
#
# Ideally, I'd like to be able to work with zipped folders, but there are no guarantees on that one.
#
# First goal: Write a method that can find all of our folders witih TDMS files included.
#
# Folder needs to have Slice00000#.tdms inside
#
# So:
# Slice000001.tdms
# Slice000002.tdms
# Slice000003.tdms ...
#
# ...
# Slice00000N.tdms
# for N slices
#
# The result will be a directory called "NAME, DATE, TDMS Files"
# Inside:
# \*PART 1 NAME\*, \*PHD OR CAMERA\* TDMS Files
# \*PART 2 NAME\*, \*PHD OR CAMERA\* TDMS Files
# \*PART 3 NAME\*, \*PHD OR CAMERA\* TDMS Files
# ...
# \*PART 1 NAME\*, \*PHD OR CAMERA\* TDMS Files
#
# Inside each one of those will be:
# Slice0001.csv
# Slice0002.csv
# ...
# Slice000N.csv
#
# For the N slices.

# %%
#print("Example directory path: \nC:/Users/maxah/Documents/CDME/Sept 9 2019 TDMS Parts/TDMS\n")
testPath = "C:\\Users\\maxah\\Documents\\CDME\\Sept 9 2019 TDMS Parts\\TDMS"

print("Enter directory path. Forward or backward slash doesn't matter.\n")

time.sleep(.1) #just so that the output makes sense to the user in the correct order; otherwise,
#                     the input prompt would come first and be confusing.
yesNoChar = 'n'
dir_path = ""
numFiles = 0
firstFileName = ""
while( 'y' not in yesNoChar and 'Y' not in yesNoChar):
    
    #C:\\Users\\maxah\\Documents\\CDME\\Sept 9 2019 TDMS Parts\\TDMS
    #/home/maxwell/Documents/CDME/TestDataATRQ
    if(yesNoChar == 'n' or yesNoChar == "N"):
        dir_path = input("Example path: " + "C:\\Users\\maxah\\Documents\\CDME\\Sept 9 2019 TDMS Parts\\TDMS" + "\n")  
        if("testpath" in dir_path or "TESTPATH" in dir_path):
            dir_path = testPath
    
    #dir_path = testPath
    root = os.path.abspath(os.sep)
    cwd = Path.cwd()

    if('\\' in dir_path):
        newPath = dir_path.replace("\\","/")
        dir_path = newPath
    
    
    sourceTDMSDirectory = root / Path(dir_path)        

    print("The chosen directory is: " + dir_path)   
    
    fileNames = []
    for (dirpath, dirnames, filenames) in walk(sourceTDMSDirectory):
        fileNames.extend(filenames)
        break

    tdmsFiles = []
    for fileName in sorted(fileNames):
        if ".tdms_index" not in fileName:
            tdmsFiles.append(fileName)
            numFiles = numFiles + 1
    print("Here are the contents of that directory: \n")
    length = len(tdmsFiles)
    if(length > 0):
        firstFileName = tdmsFiles[0]
    pprint(tdmsFiles)
    
    yesNoChar = input("If that is not the directory you want, hit 'n'. If that is the directory you want, hit 'y'.\n")
    
print("What are you going to call this project?\nEX: \"Nov 21 Build TDMS\"")
taskName = "Processed Stacks " + input("")
sourceTDMSDirectory = Path(dir_path)

"""
print("What do you want the batch size to be?\nRecommended values: 5 or 10. Higher batch size means higher memory usage.")
batchSize = int(input("Please enter a number: "))

"""
batchSize = 1

firstSliceNum = firstFileName[-6:-5]
#C:\\Users\\maxah\\Documents\\CDME\\Sept 9 2019 TDMS Parts\\TDMS
#/home/maxwell/Documents/CDME/TestDataATRQ
# /home/maxwell/Documents/CDME/ATRQTestFolder
# Out:
# Enter directory path. Forward or backward slash doesn't matter.
#
# Example path: C:\Users\maxah\Documents\CDME\Sept 9 2019 TDMS Parts\TDMS
# /home/maxwell/Documents/CDME/TestDataATRQ
# The chosen directory is: /home/maxwell/Documents/CDME/TestDataATRQ
# Here are the contents of that directory:
#
# ['Slice00001.tdms',
#  'Slice00002.tdms',
#  'Slice00003.tdms',
#  'Slice00004.tdms',
#  'Slice00005.tdms',
#  'Slice00006.tdms',
#  'Slice00007.tdms',
#  'Slice00008.tdms',
#  'Slice00009.tdms',
#  'Slice00010.tdms',
#  'Slice00011.tdms',
#  'Slice00012.tdms',
#  'Slice00013.tdms',
#  'Slice00014.tdms',
#  'Slice00015.tdms',
#  'Slice00016.tdms',
#  'Slice00017.tdms',
#  'Slice00018.tdms',
#  'Slice00019.tdms',
#  'Slice00020.tdms',
#  'Slice00021.tdms',
#  'Slice00022.tdms',
#  'Slice00023.tdms',
#  'Slice00024.tdms',
#  'Slice00025.tdms',
#  'Slice00026.tdms',
#  'Slice00027.tdms',
#  'Slice00028.tdms',
#  'Slice00029.tdms',
#  'Slice00030.tdms',
#  'Slice00031.tdms',
#  'Slice00032.tdms',
#  'Slice00033.tdms',
#  'Slice00034.tdms',
#  'Slice00035.tdms',
#  'Slice00036.tdms',
#  'Slice00037.tdms',
#  'Slice00038.tdms',
#  'Slice00039.tdms',
#  'Slice00040.tdms',
#  'Slice00041.tdms',
#  'Slice00042.tdms',
#  'Slice00043.tdms',
#  'Slice00044.tdms',
#  'Slice00045.tdms',
#  'Slice00046.tdms',
#  'Slice00047.tdms',
#  'Slice00048.tdms',
#  'Slice00049.tdms',
#  'Slice00050.tdms',
#  'Slice00051.tdms',
#  'Slice00052.tdms',
#  'Slice00053.tdms',
#  'Slice00054.tdms',
#  'Slice00055.tdms',
#  'Slice00056.tdms',
#  'Slice00057.tdms',
#  'Slice00058.tdms',
#  'Slice00059.tdms',
#  'Slice00060.tdms',
#  'Slice00061.tdms',
#  'Slice00062.tdms',
#  'Slice00063.tdms',
#  'Slice00064.tdms',
#  'Slice00065.tdms',
#  'Slice00066.tdms',
#  'Slice00067.tdms',
#  'Slice00068.tdms',
#  'Slice00069.tdms',
#  'Slice00070.tdms',
#  'Slice00071.tdms',
#  'Slice00072.tdms',
#  'Slice00073.tdms',
#  'Slice00074.tdms',
#  'Slice00075.tdms']
# If that is not the directory you want, hit 'n'. If that is the directory you want, hit 'y'.
# y
# What are you going to call this project?
# EX: "Nov 21 Build TDMS"
# Jan 14 Testing

# %% [markdown]
# ### Filepath now stored.
#
# Filepath is now stored and we have a handy dandy conversion from Windows file structure to a python readable format.
# Let's create a list of everything in the directory.
#
# Any ".tdms_index" files are created by using the National Instruments' "TDMS To Excel" tool, and can be ignored.
# They will just be removed from the list.

# %%
# Make a map of the file names to new file locations; 

#Make a "Processed" directory as a subdirectory one folder up

directoryBuildTime = time.time()
#sourceTDMSDirectory is where we are collecting these files

# I know these parentheses are ugly, but lemme explain.
#TdmsFile only takes a string, but I want it to work on Linux or Windows. So I'm using the Path library
# to concatenate these strings together in a way that works on both OS's. 
#   The Path lib takes a "/" as an operator to concatenate filepaths.
# Then, after I concatenate the paths, I turn them back into a string.
firstObject = TdmsFile(str(Path(str(sourceTDMSDirectory)) / Path(str(tdmsFiles[0]))))

parentDir = sourceTDMSDirectory.parent
newFolder = parentDir / str(taskName)
newFolder.mkdir(exist_ok=True, parents=True)

#Now that we have the folder: let's go in and make a subfolder for every group we've got in the TDMS files.
FolderDictionary = dict()
groups = firstObject.groups()
for part in groups:
    folderName = str(part)
    newDir = newFolder / folderName
    newDir.mkdir(exist_ok=True, parents=True)
    #print("\n \n" + str(part) + " \n" + str(newDir))
    
    FolderDictionary[str(part)] = str(newDir)
    
#pprint(FolderDictionary)
#Boom: we've now got a folder for every part, and a mapping of group name (part name) to folder name.

#Next step is to go into every TDMS's item, and write the
#associated data to a CSV inside of the folder for that name, with a good name for the slice.
#sourceTDMSDirectory

directoryBuildTime = time.time() - directoryBuildTime
print("Time to build directories was " + str(directoryBuildTime) + " seconds.\n")
# Out:
# Time to build directories was 3.3035812377929688 seconds.

# %%
#print(str(sourceTDMSDirectory) + "\\" + tdmsFiles[0])
#testTime = time.time()
openedSoFar = 0
numLayers = 0
tdmsObjects = []
numBatches = 0
populatedList = set()
sliceCounter = int(firstSliceNum) - 1
#Outermost loop: controls the number of files written, total.
while numLayers < numFiles:
    
    #Gets files from TDMS files
    #   This one isn't the outermost because I want to manage memory better.
    for file in tdmsFiles:
        
        #opens a TDMS file. Doing the same weird path-trick as before, to be OS independent.
        tdmsObjects.append( TdmsFile( str( Path(str(sourceTDMSDirectory)) / Path(str(file)) ) ) )
        numLayers+=1
        
        #Once we've got a few of the TDMS files open, transform them into CSV's.
        #   Happens every time a batch is fill (IE: every 5th file)
        if(numLayers % batchSize == 0 or numLayers == numFiles):
            
            #all of the actual file writing will happen in here
            
            processTime = time.time()
            filesComplete = 0
            #print("Block " + str(numBatches))
            #print(str(tdmsObjects) + "\n")
            
            
            colNames = []
            populatedList = set()
            
            #print(tdmsObjects)
            #print(numLayers)
            
            for tdms in tdmsObjects:
                sliceCounter = sliceCounter + 1
                groups = tdms.groups()
                #print(tdms)
                for part in groups:
                    #get the data from each group's channel and make a CSV
                    channels = tdms.group_channels(part)
        
        
                    #make a 2D array, and populate it with the arrays in this loop.
                    groupCSV = []
                    areaCol = []
                    xCol = []
                    yCol = []
                    paramCol = []
                    intensityCol = []
                    laserCol = []
                    csvCount = 0
                    #copy each channel's data to its respective frame
        
                    for channel in channels:
            
                        names = []
                        for i in channels:
                            wordList = str(i).split("/")
                            name = wordList[-1]
                            name = name.strip(">")
                            name = name.strip("'")
                            names.append(name)
                        colNames = names    
                        #pprint(channel.data)
                        name = channel.channel
                        data = channel.data
            
                        if(names[0] in name):
                            areaCol = data
                        elif(names[1] in name):
                            xCol = data
                        elif(names[2] in name):
                            yCol = data
                        elif(names[3] in name):
                            paramCol = data
                        elif(names[4] in name):
                            intensityCol = data
                        elif(names[5] in name):
                            laserCol = data
                        groupCSV.append(data)
                        csvCount += 1
            
                    csvFileLocation = FolderDictionary[str(part)]
                
                    #I tried avoiding this earlier, but here I'm just checking the os. If unix, then use
                    #  the unix file delimiter (forwardslash). If windows, then use the backslash delimiter.
                    if(os.name is "posix"):
                        sliceFileName = str(csvFileLocation) + "/Slice000" + str(sliceCounter) + ".csv"
                    elif(os.name is "nt"):
                        sliceFileName = str(csvFileLocation) + "\\Slice000" + str(sliceCounter) + ".csv"
                        
                    
                    with open(sliceFileName, mode="w", newline = "") as csvfile:
                        wr = csv.writer(csvfile, quoting=csv.QUOTE_ALL, dialect="excel")
                        wr.writerow(names)
                        
                        #if len(areaCol) > 1 means:
                        #if there are data points in here
                        # But what if there straight up aren't any columns to begin with??
                        
                        # IN that case then I need to identify if there are no rows
                        
                        if(len(areaCol > 1)):
                            for rows in range(0,len(areaCol - 1) ):#- 1):
                                #print(str(len(areaCol)) + "\n")
                                
                                # THIS IS A PROBLEM LINE
                                # With this line: I need to check if there are things here,
                                #   and not write the row if that's the case.
                                # Alternative: a try / catch on this bad boy?
                                
                                try:
                                    #print("Writing file: " + str(sliceFileName) + "\n")
                                    row = [areaCol[rows], xCol[rows], yCol[rows], paramCol[rows], intensityCol[rows], laserCol[rows]]
                                    wr.writerow(row)
                                    filesComplete = filesComplete + 1
                                except IndexError: 
                                    print("IndexError. Possibly no data for that part anymore?")
                                    print("While writing file: " + str(sliceFileName) + "\n")
                            populatedList.add(part)
                
            
            processTime = time.time() - processTime
            print("\nTime for " + str(filesComplete) + " was " + str(processTime) + " seconds.")
            #print("Or " + str(processTime / (sliceCounter - int(firstSliceNum) + 1)) + " seconds per layer.\n")

            
            #end operation space
            #this declaration clears the memory for the tdms objects
            tdmsObjects = []
            numBatches = numBatches + 1
        
    

    
#endTime = time.time()

#timeLength = endTime - testTime
#this block takes roughly 13.49 seconds on my machine -- 
#print("All TDMS objects read in, took " + str(timeLength) + " seconds.\n" + str((timeLength)/5) + " seconds per layer.\n")
#or roughly 2.7 seconds per layer. That isn't ideal, 
#since it's the price we can stand to pay for every access of a TDMS object.
# Out:
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice0001.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice0001.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice0001.csv
#
#
# Time for this batch was 9.319116115570068 seconds.
# Or 9.319116115570068 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice0002.csv
#
#
# Time for this batch was 10.986865043640137 seconds.
# Or 5.493432521820068 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice0003.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice0003.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice0003.csv
#
#
# Time for this batch was 9.736668825149536 seconds.
# Or 3.2455562750498452 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice0004.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice0004.csv
#
#
# Time for this batch was 11.739707231521606 seconds.
# Or 2.9349268078804016 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice0005.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00109_op2_Pad_1_s_cls/Slice0005.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice0005.csv
#
#
# Time for this batch was 11.683348894119263 seconds.
# Or 2.3366697788238526 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice0006.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice0006.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice0006.csv
#
#
# Time for this batch was 11.997760534286499 seconds.
# Or 1.9996267557144165 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice0007.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice0007.csv
#
#
# Time for this batch was 10.616012573242188 seconds.
# Or 1.516573224748884 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice0008.csv
#
#
# Time for this batch was 12.394968748092651 seconds.
# Or 1.5493710935115814 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice0009.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00109_op2_Pad_1_s_cls/Slice0009.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice0009.csv
#
#
# Time for this batch was 13.513220071792603 seconds.
# Or 1.5014688968658447 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00010.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00010.csv
#
#
# Time for this batch was 13.150459289550781 seconds.
# Or 1.3150459289550782 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice00011.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00011.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice00011.csv
#
#
# Time for this batch was 12.161617994308472 seconds.
# Or 1.1056016358462246 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00012.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00012.csv
#
#
# Time for this batch was 13.988588809967041 seconds.
# Or 1.1657157341639202 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00013.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00013.csv
#
#
# Time for this batch was 14.175045013427734 seconds.
# Or 1.0903880779559796 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00014.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00014.csv
#
#
# Time for this batch was 14.243677854537964 seconds.
# Or 1.017405561038426 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00015.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00015.csv
#
#
# Time for this batch was 13.406879663467407 seconds.
# Or 0.8937919775644938 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00016.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00016.csv
#
#
# Time for this batch was 14.773073673248291 seconds.
# Or 0.9233171045780182 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00017.csv
#
#
# Time for this batch was 15.02456021308899 seconds.
# Or 0.88379765959347 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00018.csv
# Time for this batch was 14.873124122619629 seconds.
# Or 0.8262846734788682 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00019.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00206_op2_Pad_2_s_6_cls/Slice00019.csv
#
#
# Time for this batch was 13.918100118637085 seconds.
# Or 0.7325315851914255 seconds per layer.
#
#
# Time for this batch was 15.767757892608643 seconds.
# Or 0.7883878946304321 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00021.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice00021.csv
#
#
# Time for this batch was 15.641979694366455 seconds.
# Or 0.7448561759222121 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00022.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00145_op2_ATRQ_25mm_triangle_s_cls/Slice00022.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00022.csv
#
#
# Time for this batch was 17.1796452999115 seconds.
# Or 0.7808929681777954 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00023.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice00023.csv
#
#
# Time for this batch was 17.063905715942383 seconds.
# Or 0.741908944171408 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00024.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00109_op2_Pad_1_s_cls/Slice00024.csv
#
#
# Time for this batch was 16.918843269348145 seconds.
# Or 0.704951802889506 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00025.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00025.csv
#
#
# Time for this batch was 17.06155490875244 seconds.
# Or 0.6824621963500976 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00026.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00026.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00026.csv
#
#
# Time for this batch was 16.934489965438843 seconds.
# Or 0.6513265371322632 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00027.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00027.csv
#
#
# Time for this batch was 17.560275316238403 seconds.
# Or 0.650380567268089 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00028.csv
#
#
# Time for this batch was 18.10586714744568 seconds.
# Or 0.6466381124087742 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice00029.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00029.csv
#
#
# Time for this batch was 17.775329113006592 seconds.
# Or 0.6129423832071239 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00030.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00030.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice00030.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00030.csv
#
#
# Time for this batch was 17.717106580734253 seconds.
# Or 0.5905702193578084 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00031.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00031.csv
#
#
# Time for this batch was 15.265017986297607 seconds.
# Or 0.4924199350418583 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00032.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice00032.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00032.csv
#
#
# Time for this batch was 17.666190147399902 seconds.
# Or 0.552068442106247 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00033.csv
#
#
# Time for this batch was 17.26434564590454 seconds.
# Or 0.5231619892698346 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00034.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice00034.csv
#
#
# Time for this batch was 16.55366587638855 seconds.
# Or 0.4868725257761338 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00035.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00206_op2_Pad_2_s_6_cls/Slice00035.csv
#
#
# Time for this batch was 18.856393098831177 seconds.
# Or 0.5387540885380336 seconds per layer.
#
#
# Time for this batch was 18.532757997512817 seconds.
# Or 0.5147988332642449 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00037.csv
#
#
# Time for this batch was 17.969665050506592 seconds.
# Or 0.48566662298666463 seconds per layer.
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00109_op2_Pad_1_s_cls/Slice00038.csv
#
#
# Time for this batch was 15.70775318145752 seconds.
# Or 0.41336192582782944 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00039.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00039.csv
#
#
# Time for this batch was 16.10663866996765 seconds.
# Or 0.41299073512737566 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00040.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00040.csv
#
#
# Time for this batch was 16.796297073364258 seconds.
# Or 0.4199074268341064 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00041.csv
#
#
# Time for this batch was 15.853578567504883 seconds.
# Or 0.38667264798792395 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00042.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00042.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00042.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00109_op2_Pad_1_s_cls/Slice00042.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00206_op2_Pad_2_s_6_cls/Slice00042.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00042.csv
#
#
# Time for this batch was 15.38587212562561 seconds.
# Or 0.36633028870537165 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00043.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00043.csv
#
#
# Time for this batch was 16.93295645713806 seconds.
# Or 0.39378968504972234 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00044.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00044.csv
#
#
# Time for this batch was 16.382238149642944 seconds.
# Or 0.3723235943100669 seconds per layer.
#
#
# Time for this batch was 16.506413221359253 seconds.
# Or 0.3668091826968723 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00046.csv
#
#
# Time for this batch was 15.55846643447876 seconds.
# Or 0.33822753118432086 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00047.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00047.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00047.csv
#
#
# Time for this batch was 16.957655429840088 seconds.
# Or 0.36080117935829975 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00048.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00048.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00206_op2_Pad_2_s_6_cls/Slice00048.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00048.csv
#
#
# Time for this batch was 17.05418586730957 seconds.
# Or 0.3552955389022827 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00049.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00109_op2_Pad_1_s_cls/Slice00049.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00049.csv
#
#
# Time for this batch was 16.461710691452026 seconds.
# Or 0.3359532794173883 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00050.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00050.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00050.csv
#
#
# Time for this batch was 16.35983681678772 seconds.
# Or 0.3271967363357544 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00051.csv
#
#
# Time for this batch was 12.796399354934692 seconds.
# Or 0.25090979127322927 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00052.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00052.csv
#
#
# Time for this batch was 13.787022590637207 seconds.
# Or 0.2651350498199463 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00053.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00053.csv
#
#
# Time for this batch was 12.569547414779663 seconds.
# Or 0.23716127197697479 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice00054.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00054.csv
#
#
# Time for this batch was 11.991555452346802 seconds.
# Or 0.22206584171012597 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00055.csv
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00055.csv
#
#
# Time for this batch was 13.129100799560547 seconds.
# Or 0.23871092362837357 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00056.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00056.csv
#
#
# Time for this batch was 12.913623094558716 seconds.
# Or 0.23060041240283422 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00057.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00057.csv
#
#
# Time for this batch was 12.041297197341919 seconds.
# Or 0.21125082802354245 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00058.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00058.csv
#
#
# Time for this batch was 12.153783798217773 seconds.
# Or 0.2095479965209961 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00059.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00059.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00109_op2_Pad_1_s_cls/Slice00059.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00059.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00206_op2_Pad_2_s_6_cls/Slice00059.csv
#
#
# Time for this batch was 14.662739038467407 seconds.
# Or 0.24852100065198995 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00060.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00145_op2_ATRQ_25mm_triangle_s_cls/Slice00060.csv
#
#
# Time for this batch was 16.824045658111572 seconds.
# Or 0.28040076096852623 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00061.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00061.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice00061.csv
#
#
# Time for this batch was 14.794060230255127 seconds.
# Or 0.24252557754516602 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice00062.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00062.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00145_op2_ATRQ_25mm_triangle_s_cls/Slice00062.csv
#
#
# Time for this batch was 12.594336748123169 seconds.
# Or 0.20313446367940596 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00063.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00063.csv
#
#
# Time for this batch was 12.18899655342102 seconds.
# Or 0.19347613576858763 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00048_op2_pole_s_cls/Slice00064.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice00064.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00064.csv
#
#
# Time for this batch was 12.547728300094604 seconds.
# Or 0.1960582546889782 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00065.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00065.csv
#
#
# Time for this batch was 11.914302587509155 seconds.
# Or 0.18329696288475625 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00066.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00066.csv
#
#
# Time for this batch was 11.839003562927246 seconds.
# Or 0.17937884186253403 seconds per layer.
#
#
# Time for this batch was 12.562410354614258 seconds.
# Or 0.18749866200916804 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00068.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00207_op1_Pad_1_s_2_cls/Slice00068.csv
#
#
# Time for this batch was 13.29674482345581 seconds.
# Or 0.19554036505082073 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00005_op1_Pad_3_s_7_cls/Slice00069.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00119_op1_Pad_4_s_5_cls/Slice00069.csv
#
#
# Time for this batch was 15.208733558654785 seconds.
# Or 0.22041642838630124 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00004_op1_Pad_2_s_4_cls/Slice00070.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00070.csv
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00089_op1_ATRQ_25mm_triangle_s_2_cls/Slice00070.csv
#
#
# Time for this batch was 13.189970970153809 seconds.
# Or 0.18842815671648297 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00071.csv
#
#
# Time for this batch was 13.588576078414917 seconds.
# Or 0.19138839547063263 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/0_00047_op1_pole_s_cls/Slice00072.csv
# Time for this batch was 13.86091661453247 seconds.
# Or 0.19251273075739542 seconds per layer.
#
#
# Time for this batch was 12.825100421905518 seconds.
# Or 0.17568630714939065 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00205_op2_Pad_3_s_3_cls/Slice00074.csv
#
#
# Time for this batch was 14.83765196800232 seconds.
# Or 0.20050881037840973 seconds per layer.
#
# IndexError. Possibly no data for that part anymore?
# While writing file: /home/maxwell/Documents/CDME/Processed Stacks Jan 14 Testing/1_00006_op2_Pad_4_s_8_cls/Slice00075.csv
#
#
# Time for this batch was 17.437901496887207 seconds.
# Or 0.23250535329182942 seconds per layer.

# %% [markdown]
# Time information:
# It's taking roughly 30 seconds per layer, but that's probably pretty variable.
# If you want to do 800 layers then, we're looking at 2400 seconds or 40 minutes.
# This might be the kind of script you set up and run and leave overnight once it's finished.
# Speed may also depend on the computer it's being performed on -- the slowdown is likely the read/writes happening, so the
# hard disk in the desktops here at the CDME could be slower than my machine's SSD.

# %%
def get_size(start_path = '.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            # skip if it is symbolic link
            if not os.path.islink(fp):
                total_size += os.path.getsize(fp)

    return total_size

def count_files(start_path = "."):
    total_files = 0
    return(len(os.listdir(start_path)))
    

#print(get_size(), 'bytes')

# %%
partsDeleted = 0
partsRemaining = 0
for k, v in FolderDictionary.items():
    byteSize = get_size(v)
    fileCount = count_files(v)
    minimumBytes = 62 * int(fileCount) #61 is the number of bytes contained in the headers.
    #If a folder has less than 62 bytes per file, then delete the folder.
    #Note: if there are some empty files in a folder, leave the entire thing for now.
    if (byteSize < minimumBytes):
        #delete the directory v, since many of the folders don't actually contain any data
        partsDeleted = partsDeleted + 1
        shutil.rmtree(v)
    else:
        partsRemaining = partsRemaining + 1

# Boom: now it only keeps those which have items inside.
print("Finished.\n")
pprint(populatedList)
        
endTime = time.time()
runTime = endTime - startTime
print("\n***FINISHED REPORT***")
print("\n" + "Runtime was: " + str(runTime) + " seconds.")
print("Number of layers written was: " + str(numLayers) + " layers.")
print("Number of parts with no data was: " + str(partsDeleted) + " parts.")
print("Number of parts with data was: " + str(partsRemaining) + " parts.")
print("Parts with data: ")

#input hold; causes the program to freeze before exiting.
exit = input("Finished: type the X key to exit.")
time.sleep(.01)
if("x" not in exit and "X" not in exit):
    input()
# Out:
# Finished.
#
# {'0_00004_op1_Pad_2_s_4_cls',
#  '0_00005_op1_Pad_3_s_7_cls',
#  '0_00047_op1_pole_s_cls',
#  '0_00089_op1_ATRQ_25mm_triangle_s_2_cls',
#  '0_00119_op1_Pad_4_s_5_cls',
#  '0_00207_op1_Pad_1_s_2_cls',
#  '1_00006_op2_Pad_4_s_8_cls',
#  '1_00048_op2_pole_s_cls',
#  '1_00109_op2_Pad_1_s_cls',
#  '1_00145_op2_ATRQ_25mm_triangle_s_cls',
#  '1_00205_op2_Pad_3_s_3_cls',
#  '1_00206_op2_Pad_2_s_6_cls'}
#
# ***FINISHED REPORT***
#
# Runtime was: 1497.672353029251 seconds.
# Number of layers written was: 75 layers.
# Number of parts with no data was: 474 parts.
# Number of parts with data was: 12 parts.
# Parts with data:
# Finished: type the X key to exit.x
